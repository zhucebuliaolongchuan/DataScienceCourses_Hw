# %% [markdown]
# ### Introduction to Data Science
# ## Homework 3: Due 5pm to My Mailbox (2nd Floor, 19 W 4th St) Wednesday April 19th

# %% [markdown]
# #### Student Name:  Chuan Long
#
# #### Student Netid: cl4076

# %% [markdown]
# In this assignment we will be looking at data generated by particle physicists to test whether machine learning can help classify whether certain particle decay experiments identify the presence of a Higgs Boson. One does not need to know anything about particle physics to do well here, but if you are curious, full feature and data descriptions can be found here:
#
# - https://www.kaggle.com/c/higgs-boson/data
# - http://higgsml.lal.in2p3.fr/files/2014/04/documentation_v1.8.pdf
#
# The goal of this assignment is to learn to use cross-validation for model selection. We’ll also use learning curve analysis to understand how well different algorithms make use of limited data. For more documentation on cross-validation with Python, you can consult the following:
#
# - http://scikit-learn.org/stable/modules/cross_validation.html#cross-validation

# %% [markdown]
# ### Part 1: Data preparation
# Create a data preparation and cleaning function that does the following:
# - Has a single input that is a file name string
# - Reads data (the data is comma separated, has a row header and the first column `EventID` is the index) into a pandas `dataframe`
# - Cleans the data
#   - Convert the feature `Label` to numeric (choose the minority class to be equal to 1)
#     - Create a feature `Y` with numeric label
#     - Drop the feature `Label`
#   - If a feature has missing values (i.e., `-999`):
#     - Create a dummy variable for the missing value
#       - Call the variable `orig_var_name` + `_mv` where `orig_var_name` is the name of the actual var with a missing value
#       - Give this new variable a 1 if the original variable is missing
#     - Replace the missing value with the average of the feature (make sure to compute the mean on records where the value isn't missing). You may find pandas' `.replace()` function useful.
# - After the above is done, rescales the data so that each feature has zero mean and unit variance (hint: look up sklearn.preprocessing)
# - Returns the cleaned and rescaled dataset
#
# Hint: as a guide, this function can easily be done in less than 15 lines.

# %%
import collections
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.cross_validation import KFold

# %%
# Make sure what the professor asks for
def cleanBosonData(infile_name):
    # Read the data as dataframe object
    data = pd.read_csv(infile_name, sep = ',', header = 0, index_col = 0)
    # Count the type of data.Label
    labels = data.Label.value_counts(ascending = False).index.tolist()
    # Create Feature Y to be a Numeric Label
    Y = data['Label'].apply(lambda x : labels.index(x))
    # Drop the feature Label
    data = data.drop('Label', 1)
    # Create dummy feature and fill the missing value with the mean of original attribute
    for col in data.columns:
        if (data[col] == -999).any():
            new_col = str(col) + '_mv'
            data[new_col] = data[col].apply(lambda x : 1 if x == -999 else 0)
            col_mean = data[col].dropna().mean(axis = 0)
            data[col] = data[col].replace(-999, col_mean)
    # Standardize the data set
    data_scale = preprocessing.scale(data)
    # Transform the numpy array to dataframe object
    data_clean = pd.DataFrame(data_scale, columns = data.columns, index = data.index)
    # Add the numeric label value
    data_clean = data_clean.assign(Y = Y.values)
    return data_clean

# %%
file_path = 'data/boson_training_cut_2000.csv'
clean_data = cleanBosonData(file_path)
clean_data.describe()
# Out:
#        DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis      DER_pt_h  \
# count  1.999000e+03                 1.999000e+03  1.999000e+03  1.999000e+03
# mean  -3.315674e-17                -1.710599e-16  1.834173e-17  5.020718e-17
# std    1.000250e+00                 1.000250e+00  1.000250e+00  1.000250e+00
# min   -1.852556e+00                -1.463197e+00 -1.870118e+00 -8.914087e-01
# 25%   -2.282273e-01                -8.395946e-01 -5.573124e-01 -7.073110e-01
# 50%    9.913407e-02                -7.199834e-02 -1.731902e-01 -3.106130e-01
# 75%    4.348493e-01                 7.229055e-01  3.270757e-01  3.368307e-01
# max    8.521411e+00                 6.280756e+00  8.862150e+00  7.608615e+00
#
#        DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# count          1.999000e+03      1.999000e+03         1.999000e+03
# mean          -4.033236e-16     -2.874695e-16        -1.490665e-16
# std            1.000250e+00      1.000250e+00         1.000250e+00
# min           -6.284684e-01     -5.696512e-01        -6.284610e-01
# 25%           -6.284684e-01     -5.696512e-01        -6.284610e-01
# 50%           -6.284684e-01     -5.696512e-01        -6.284610e-01
# 75%            1.585199e+00      8.602086e-01         1.577605e+00
# max            1.607632e+00      7.104658e+00         1.625369e+00
#
#        DER_deltar_tau_lep    DER_pt_tot  DER_mass_MMC_mv  \
# count        1.999000e+03  1.999000e+03     1.999000e+03
# mean        -6.431407e-17  2.282650e-17     1.146879e-16
# std          1.000250e+00  1.000250e+00     1.000250e+00
# min         -2.762886e+00 -9.067964e-01    -4.052653e-01
# 25%         -6.717898e-01 -7.721390e-01    -4.052653e-01
# 50%          1.609937e-01 -2.713372e-01    -4.052653e-01
# 75%          7.131370e-01  4.345566e-01    -4.052653e-01
# max          3.989448e+00  9.699160e+00     2.467519e+00
#
#        DER_deltaeta_jet_jet_mv  DER_mass_jet_jet_mv  DER_prodeta_jet_jet_mv  \
# count             1.999000e+03         1.999000e+03            1.999000e+03
# mean             -4.754132e-17        -4.754132e-17           -4.754132e-17
# std               1.000250e+00         1.000250e+00            1.000250e+00
# min              -1.591164e+00        -1.591164e+00           -1.591164e+00
# 25%              -1.591164e+00        -1.591164e+00           -1.591164e+00
# 50%               6.284708e-01         6.284708e-01            6.284708e-01
# 75%               6.284708e-01         6.284708e-01            6.284708e-01
# max               6.284708e-01         6.284708e-01            6.284708e-01
#
#                  Y
# count  1999.000000
# mean      0.333167
# std       0.471463
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# ### Part 2: Basic evaluations
# In this part you will build an out-of-the box logistic regression (LR) model and support vector machine (SVM). You will then plot ROC for the LR and SVM model.

# %% [markdown]
# 1\. Clean the two data files included in this assignment (`data/boson_training_cut_2000.csv` and `data/boson_testing_cut.csv`) and use them as training and testing data sets.

# %%
data_train = cleanBosonData("data/boson_training_cut_2000.csv")
data_test = cleanBosonData("data/boson_testing_cut.csv")

# %% [markdown]
# 2\. On the training set, build the following models:
#
# - A logistic regression using sklearn's `linear_model.LogisticRegression()`. For this model, use `C=1e30`.
# - An SVM using sklearn's `svm.svc()`. For this model, specify that `kernel="linear"`.
#
# For each model above, plot the ROC curve of both models on the same plot. Make sure to use the test set for computing and plotting. In the legend, also print out the Area Under the ROC (AUC) for reference.

# %%
import matplotlib
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, auc
from sklearn.cross_validation import KFold
# %matplotlib inline

lr = LogisticRegression(C = 1e30)
lr = lr.fit(data_train.drop('Y', 1), data_train.Y)
lr_preds = lr.decision_function(data_test.drop('Y', 1))
# lr_preds = lr.predict_proba(data_test.drop('Y', 1))[:, 1]

svm = SVC(kernel = 'linear', probability = True)
svm = svm.fit(data_train.drop('Y', 1), data_train.Y)
svm_preds = svm.decision_function(data_test.drop('Y', 1))
# svm_preds = svm.predict_proba(data_test.drop('Y', 1))[:, 1]

def plotROC(label_string, truth, preds):
    fpr, tpr, thresholds = roc_curve(truth, preds)    
    roc_auc = auc(fpr, tpr)
    if roc_auc < 0.5:
        fpr, tpr, thresholds = roc_curve(truth, -1 * preds)
        roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label = label_string + ' (AUC = %0.5f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.title('ROC')
    plt.legend(loc="best")

plt.figure(figsize = (20, 10))
plotROC('lr', data_test.Y, lr_preds)
plotROC('svm', data_test.Y, svm_preds)

# %% [markdown]
# 3\. Which of the two models is generally better at ranking the test set? Are there any classification thresholds where the model identified above as "better" would underperform the other in a classification metric (such as TPR)?

# %% [markdown]
# * As we can see, the logisticRegression method is a bit better than SVM method at ranking the test set, since that the AUC value of LR method is higher than the AUC value of SVM.
# * Yes, when the TPR value is less than approximately 0.15(threshold), the SVM method is a bit better than LR method.

# %% [markdown]
# ### Part 3: Model selection with cross-validation
# We think we might be able to improve the performance of the SVM if we perform a grid search on the hyper-parameter $C$.  Because we only have 1000 instances, we will have to use cross-validation to find the optimal $C$.

# %% [markdown]
# 1\. Write a cross-validation function that does the following:
# - Takes as inputs a dataset, a label name, # of splits/folds (`k`), a sequence of values for $C$ (`cs`)
# - Performs two loops
#   - Outer Loop: `for each f in range(k)`:
#     - Splits the data into `data_train` & `data_validate` according to cross-validation logic
#   - Inner Loop: `for each c in cs`:
#     - Trains an SVM on training split with `C=c, kernel="linear"`
#     - Computes AUC_c_k on validation data
#     - Stores AUC_c_k in a  dictionary of values
# - Returns a dictionary, where each key-value pair is: `c:[auc-c1,auc-c2,..auc-ck]`

# %%
def xValSVM(dataset, label_name, k, cs):
    aucs = collections.defaultdict(list)
    kf = KFold(n = dataset.shape[0], n_folds = k)
    for train_index, validate_index in kf:
        data_train = dataset.iloc[train_index]
        data_validate = dataset.iloc[validate_index]
        for c in cs:
            svm = SVC(C = c, kernel = 'linear', probability = True)
            svm = svm.fit(data_train.drop(label_name, 1), data_train[label_name])
            svm_preds = svm.decision_function(data_validate.drop(label_name, 1))
            fpr, tpr, thresholds = roc_curve(data_validate[label_name], svm_preds)
            aucs[c].append(auc(fpr, tpr))
    return aucs

# %% [markdown]
# 2\. Using the function written above, do the following:
# - Generate a sequence of 10 $C$ values in the interval `[10^(-8), ..., 10^1]` (i.e., do all powers of 10 from -8 to 1).
# 2.	Call aucs = xValSVM(train, ‘Y’, 10, cs)
# 3.	For each c in cs, get mean(AUC) and StdErr(AUC)
# 4.	Compute the value for max(meanAUC-StdErr(AUC)) across all values of c.
# 5.	Generate a plot with the following:
# a.	Log10(c) on the x-axis
# b.	1 series with mean(AUC) for each c
# c.	1 series with mean(AUC)-stderr(AUC) for each c (use ‘k+’ as color pattern)
# d.	1 series with mean(AUC)+stderr(AUC) for each c (use ‘k--‘ as color pattern)
# e.	a reference line for max(AUC-StdErr(AUC)) (use ‘r’ as color pattern)
#
# Then answer the question: Did the model parameters selected beat the out-of-the-box model for SVM?

# %%
# Sample the dataset to fetch 1000 rows as required
data_train = data_train.sample(frac = 0.5)
cs = [10 ** i for i in range(-8, 2)]
# Call the gridsearchCV function
aucs = xValSVM(data_train, 'Y', 10, cs)

# %%
data_train.describe()
# Out:
#        DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis     DER_pt_h  \
# count   1000.000000                  1000.000000   1000.000000  1000.000000
# mean       0.004544                     0.027095      0.036793     0.003260
# std        1.020630                     1.023615      1.043577     0.992948
# min       -1.852556                    -1.461932     -1.870118    -0.891329
# 25%       -0.233730                    -0.841748     -0.568390    -0.718284
# 50%        0.118002                    -0.044676     -0.159188    -0.319206
# 75%        0.458277                     0.759070      0.359670     0.330426
# max        7.531096                     5.797473      6.682671     6.603901
#
#        DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# count           1000.000000       1000.000000          1000.000000
# mean              -0.011382          0.000319            -0.011515
# std                0.994972          1.030987             0.994760
# min               -0.628468         -0.569651            -0.628461
# 25%               -0.628468         -0.569651            -0.628461
# 50%               -0.628468         -0.569651            -0.628461
# 75%                1.585228          0.848725             1.575343
# max                1.607632          7.104658             1.625369
#
#        DER_deltar_tau_lep   DER_pt_tot  DER_mass_MMC_mv  \
# count         1000.000000  1000.000000      1000.000000
# mean             0.005060    -0.016527         0.025652
# std              1.011690     0.941796         1.026303
# min             -2.762886    -0.903122        -0.405265
# 25%             -0.704096    -0.772054        -0.405265
# 50%              0.178615    -0.326592        -0.405265
# 75%              0.715095     0.434907        -0.405265
# max              2.887772     5.634010         2.467519
#
#        DER_deltaeta_jet_jet_mv  DER_mass_jet_jet_mv  DER_prodeta_jet_jet_mv  \
# count              1000.000000          1000.000000             1000.000000
# mean                  0.011412             0.011412                0.011412
# std                   0.994924             0.994924                0.994924
# min                  -1.591164            -1.591164               -1.591164
# 25%                  -1.591164            -1.591164               -1.591164
# 50%                   0.628471             0.628471                0.628471
# 75%                   0.628471             0.628471                0.628471
# max                   0.628471             0.628471                0.628471
#
#                  Y
# count  1000.000000
# mean      0.339000
# std       0.473607
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
# Translate the dictionary to dataframe for better visualization
auc_df = pd.DataFrame.from_dict(aucs)
auc_df
# Out:
#    1.000000e-08  1.000000e-07  1.000000e-06  1.000000e-05  1.000000e-04  \
# 0      0.822814      0.822814      0.822814      0.822814      0.817672
# 1      0.671415      0.671415      0.671415      0.698529      0.698529
# 2      0.601128      0.601128      0.601128      0.590278      0.647135
# 3      0.719846      0.719846      0.719846      0.729715      0.732456
# 4      0.826484      0.826484      0.826484      0.840183      0.817859
# 5      0.723026      0.723026      0.723026      0.733361      0.747830
# 6      0.682987      0.682987      0.682987      0.682171      0.714810
# 7      0.709962      0.709962      0.709962      0.722993      0.739386
# 8      0.728860      0.728860      0.728860      0.750000      0.772059
# 9      0.702763      0.702763      0.702763      0.711230      0.744207
#
#    1.000000e-03  1.000000e-02  1.000000e-01  1.000000e+00  1.000000e+01
# 0      0.817672      0.817204      0.800374      0.794764      0.786816
# 1      0.701746      0.704963      0.729779      0.728860      0.729320
# 2      0.644097      0.645833      0.693576      0.686632      0.690972
# 3      0.737390      0.741228      0.740680      0.746711      0.747259
# 4      0.822933      0.818874      0.823440      0.822425      0.825469
# 5      0.746589      0.745763      0.743696      0.744109      0.743696
# 6      0.718482      0.714402      0.709506      0.719298      0.715218
# 7      0.736444      0.737285      0.726776      0.722573      0.717528
# 8      0.771140      0.772059      0.783548      0.783088      0.784926
# 9      0.741979      0.744207      0.767380      0.771836      0.771390

# %%
auc_df.describe()
# Out:
#        1.000000e-08  1.000000e-07  1.000000e-06  1.000000e-05  1.000000e-04  \
# count     10.000000     10.000000     10.000000     10.000000     10.000000
# mean       0.713277      0.713277      0.713277      0.712725      0.718286
# std        0.061907      0.061907      0.061907      0.062403      0.063599
# min        0.605903      0.605903      0.605903      0.605903      0.622332
# 25%        0.676421      0.676421      0.676421      0.672285      0.677543
# 50%        0.720533      0.720533      0.720533      0.720533      0.732658
# 75%        0.756367      0.756367      0.756367      0.756367      0.758886
# max        0.789661      0.789661      0.789661      0.789661      0.820034
#
#        1.000000e-03  1.000000e-02  1.000000e-01  1.000000e+00  1.000000e+01
# count     10.000000     10.000000     10.000000     10.000000     10.000000
# mean       0.721910      0.723287      0.730476      0.733395      0.731458
# std        0.064014      0.064938      0.060413      0.053867      0.048816
# min        0.609375      0.607639      0.621528      0.645833      0.654514
# 25%        0.674465      0.675802      0.699352      0.693251      0.693662
# 50%        0.738761      0.739325      0.727118      0.740642      0.736185
# 75%        0.755709      0.759862      0.772680      0.759990      0.763394
# max        0.823430      0.826825      0.830221      0.811545      0.811545

# %%
x = np.log10(cs)
plt.figure(figsize = (20, 10))
# 1 series with mean(AUC) for each c
plt.plot(x, auc_df.describe().loc['mean'], label = 'mean(AUC)')
# 1 series with mean(AUC)-stderr(AUC) for each c (use ‘k+’ as color pattern)
plt.plot(x, auc_df.describe().loc['mean'] - auc_df.describe().loc['std'], 'k+', label = 'mean(AUC)-stderr(AUC)')
# 1 series with mean(AUC)+stderr(AUC) for each c (use ‘k--‘ as color pattern)
plt.plot(x, auc_df.describe().loc['mean'] + auc_df.describe().loc['std'], 'k--', label = 'mean(AUC)+stderr(AUC)')
# a reference line for max(AUC-StdErr(AUC)) (use ‘r’ as color pattern)
plt.plot(x, [max_diff] * x.shape[0], 'r', label = 'max(mean(AUC)-stderr(AUC))')
plt.legend(loc = 'best')
plt.xlabel('log10 of cs')
plt.ylabel('AUC')
plt.title('xValSVM')

# %% [markdown]
# * No. It can not beat the out-of-the-box model at this time.
#     * As we can see, the curve of the mean(AUC) is not higher then the AUC value of the previous SVM model. One of the reason why this would happen is that the cross validation would cause biase to some extend. In this case, the smaller dataset would weaken the performance of the SVM model. Even though the little difference between the gap is not so persuasive, it is reasonable to say that the parameter selected model doesn't beat the out-of-the-box model.

# %% [markdown]
# 3\. Which of the two algorithms are more suitable for smaller sample sizes, given the set of features? If it costs twice the investment to run enough experiments to double the data, do you think it is a worthy investment?

# %%
# Experiment the same pipeline with LR method
def xValLR(dataset, label_name, k, cs):
    aucs = collections.defaultdict(list)
    kf = KFold(n = dataset.shape[0], n_folds = k)
    for train_index, validate_index in kf:
        data_train = dataset.iloc[train_index]
        data_validate = dataset.iloc[validate_index]
        for c in cs:
            lr = LogisticRegression(C = c)
            lr = lr.fit(data_train.drop('Y', 1), data_train.Y)
            lr_preds = lr.decision_function(data_validate.drop('Y', 1))
            fpr, tpr, thresholds = roc_curve(data_validate[label_name], lr_preds)
            aucs[c].append(auc(fpr, tpr))
    return aucs

# %%
aucs_lr = xValLR(data_train, 'Y', 10, cs)

# %%
aucs_lr_df = pd.DataFrame.from_dict(aucs)
aucs_lr_df
# Out:
#    1.000000e-08  1.000000e-07  1.000000e-06  1.000000e-05  1.000000e-04  \
# 0      0.750339      0.750339      0.750339      0.748078      0.738580
# 1      0.714167      0.714167      0.714167      0.732500      0.745000
# 2      0.728037      0.728037      0.728037      0.704077      0.725935
# 3      0.655824      0.655824      0.655824      0.665055      0.650549
# 4      0.767143      0.767143      0.767143      0.785238      0.775238
# 5      0.742171      0.742171      0.742171      0.744316      0.740455
# 6      0.776999      0.776999      0.776999      0.764843      0.778869
# 7      0.725694      0.725694      0.725694      0.727679      0.722718
# 8      0.660232      0.660232      0.660232      0.653368      0.661519
# 9      0.770485      0.770485      0.770485      0.765766      0.777349
#
#    1.000000e-03  1.000000e-02  1.000000e-01  1.000000e+00  1.000000e+01
# 0      0.739937      0.748530      0.780190      0.781999      0.781095
# 1      0.743750      0.750417      0.755000      0.752917      0.755833
# 2      0.741068      0.736864      0.696511      0.691047      0.688104
# 3      0.650989      0.657582      0.677363      0.678242      0.680440
# 4      0.777143      0.782381      0.809048      0.808571      0.807143
# 5      0.737881      0.745174      0.759760      0.764050      0.765766
# 6      0.775129      0.780739      0.794296      0.793829      0.790556
# 7      0.721726      0.724206      0.731647      0.739087      0.741567
# 8      0.658087      0.683827      0.730588      0.754183      0.755470
# 9      0.782926      0.788932      0.819820      0.822394      0.823681

# %%
aucs_lr_df.describe()
# Out:
#        1.000000e-08  1.000000e-07  1.000000e-06  1.000000e-05  1.000000e-04  \
# count     10.000000     10.000000     10.000000     10.000000     10.000000
# mean       0.729109      0.729109      0.729109      0.729092      0.731621
# std        0.042719      0.042719      0.042719      0.043259      0.044882
# min        0.655824      0.655824      0.655824      0.653368      0.650549
# 25%        0.717049      0.717049      0.717049      0.709978      0.723523
# 50%        0.735104      0.735104      0.735104      0.738408      0.739517
# 75%        0.762942      0.762942      0.762942      0.760652      0.767679
# max        0.776999      0.776999      0.776999      0.785238      0.778869
#
#        1.000000e-03  1.000000e-02  1.000000e-01  1.000000e+00  1.000000e+01
# count     10.000000     10.000000     10.000000     10.000000     10.000000
# mean       0.732863      0.739865      0.755422      0.758632      0.758965
# std        0.045866      0.042512      0.047037      0.046950      0.046614
# min        0.650989      0.657582      0.677363      0.678242      0.680440
# 25%        0.725765      0.727371      0.730853      0.742545      0.745043
# 50%        0.740502      0.746852      0.757380      0.759116      0.760800
# 75%        0.767284      0.773158      0.790770      0.790871      0.788191
# max        0.782926      0.788932      0.819820      0.822394      0.823681

# %% [markdown]
# * For AUC value, the performance of LR model is better than the performance of SVM model in this case. So we can easily make a conclusion that the LR model is more situable for smaller sample sizes than SVM model. Although this conclusion is very ambiguous and not so persuasive, because the gap between them is kind of trivial. Actually, both linear SVM and LR belong to linear classifier. For linear SVM, it is not depend on the distribution of the dataset, but LR does, and LR would be affected by all the points in one dataset. The dataset should be normalized before training with SVM model, however, LR model doesn't need to generally. But both of them would be affected by the outliners, but it is difficult to evaluate their sensitivity to outliners. Both of them have pros and cons, and it is also difficult to make a firm conclusion that which one is more suitable for smaller sample sizes.
# * No, I don't think it is a worthy investment. As we can see, the mean AUC value of the model that has been trained with 1000 rows is apprxomiately 0.72, it is very close to 0.75 that we have trained before, which is trained with 2000 rows. Actually, the size of training set which is 1000 rows is so close to unbiased, because even thought we double the dataset, it could not bring a lot improvement on AUC value.

# %% [markdown]
# 4\. Is there a reason why cross-validation might be biased? If so, in what direction is it biased? (Hint: refer to ESL figure 7.8)?

# %% [markdown]
# Yes. The size of training set would be the reason why cross-validation might be biased. As we can see from ESL figure 7.8, the performance of the classifier improves as the training set size increases. Keep increasing the size of training set, the performance of our classifier brings only a small benefit. Intuitively, the smaller dataset, the worse representativity, the higher variance, so that it would weaken the performance of SVM model. But when the size o f data set is bigger enough, the cross-validation would be closer to unbiased situation.
